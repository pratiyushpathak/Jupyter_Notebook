# %%
pip install -U scikit-image
# Out:
# Collecting scikit-image
#   Downloading scikit_image-0.22.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.22 in /home/pratiyushp/anaconda3/envs/My_Workspace/lib/python3.11/site-packages (from scikit-image) (1.26.4)
# Requirement already satisfied: scipy>=1.8 in /home/pratiyushp/anaconda3/envs/My_Workspace/lib/python3.11/site-packages (from scikit-image) (1.12.0)
# Requirement already satisfied: networkx>=2.8 in /home/pratiyushp/anaconda3/envs/My_Workspace/lib/python3.11/site-packages (from scikit-image) (3.1)
# Requirement already satisfied: pillow>=9.0.1 in /home/pratiyushp/anaconda3/envs/My_Workspace/lib/python3.11/site-packages (from scikit-image) (10.2.0)
# Collecting imageio>=2.27 (from scikit-image)
#   Downloading imageio-2.34.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image)
#   Downloading tifffile-2024.2.12-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: packaging>=21 in /home/pratiyushp/anaconda3/envs/My_Workspace/lib/python3.11/site-packages (from scikit-image) (23.1)
# Collecting lazy_loader>=0.3 (from scikit-image)
#   Downloading lazy_loader-0.3-py3-none-any.whl.metadata (4.3 kB)
# Downloading scikit_image-0.22.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 5.2 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading imageio-2.34.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.4/313.4 kB 4.3 MB/s eta 0:00:009 MB/s eta 0:00:01
# Downloading lazy_loader-0.3-py3-none-any.whl (9.1 kB)
# Downloading tifffile-2024.2.12-py3-none-any.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 8.2 MB/s eta 0:00:00
# Installing collected packages: tifffile, lazy_loader, imageio, scikit-image
# Successfully installed imageio-2.34.0 lazy_loader-0.3 scikit-image-0.22.0 tifffile-2024.2.12
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /home/pratiyushp/anaconda3/envs/My_Workspace/lib/python3.11/site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.21.2 in /home/pratiyushp/anaconda3/envs/My_Workspace/lib/python3.11/site-packages (from opencv-python) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
from skimage.color import rgb2gray
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import ndimage

# %%
image = plt.imread('/home/pratiyushp/Downloads/imag.jpeg')
image.shape
plt.imshow(image)

# %%
gray = rgb2gray(image)
cv2.imshow('img',gray)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
#
# QObject::moveToThread: Current thread (0x2c8fa90) is not the object's thread (0x2456ee0).
# Cannot move to target thread (0x2c8fa90)
